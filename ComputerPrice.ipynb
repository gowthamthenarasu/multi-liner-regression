# %%
import pandas as pd

# %%
comp = pd.read_csv('C:\\Users\\acer\\Downloads\\Computer_Data.csv')

# %%
comp.head(10)
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen   cd multi premium  ads  trend
# 0           1   1499     25   80    4      14   no    no     yes   94      1
# 1           2   1795     33   85    2      14   no    no     yes   94      1
# 2           3   1595     25  170    4      15   no    no     yes   94      1
# 3           4   1849     25  170    8      14   no    no      no   94      1
# 4           5   3295     33  340   16      14   no    no     yes   94      1
# 5           6   3695     66  340   16      14   no    no     yes   94      1
# 6           7   1720     25  170    4      14  yes    no     yes   94      1
# 7           8   1995     50   85    2      14   no    no     yes   94      1
# 8           9   2225     50  210    8      14   no    no     yes   94      1
# 9          10   2575     50  210    4      15   no    no     yes   94      1

# %%
comp.shape
# Out:
# (6259, 11)

# %%
comp.cd = comp.cd.map({'yes':1,'no':0})
comp.multi = comp.multi.map({'yes':1,'no':0})
comp.premium = comp.premium.map({'yes':1,'no':0})

# %%
comp.head(10)
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen  cd  multi  premium  ads  trend
# 0           1   1499     25   80    4      14   0      0        1   94      1
# 1           2   1795     33   85    2      14   0      0        1   94      1
# 2           3   1595     25  170    4      15   0      0        1   94      1
# 3           4   1849     25  170    8      14   0      0        0   94      1
# 4           5   3295     33  340   16      14   0      0        1   94      1
# 5           6   3695     66  340   16      14   0      0        1   94      1
# 6           7   1720     25  170    4      14   1      0        1   94      1
# 7           8   1995     50   85    2      14   0      0        1   94      1
# 8           9   2225     50  210    8      14   0      0        1   94      1
# 9          10   2575     50  210    4      15   0      0        1   94      1

# %%
comp.tail()
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen  cd  multi  premium  ads  \
# 6254        6255   1690    100   528    8      15   0      0        1   39
# 6255        6256   2223     66   850   16      15   1      1        1   39
# 6256        6257   2654    100  1200   24      15   1      0        1   39
# 6257        6258   2195    100   850   16      15   1      0        1   39
# 6258        6259   2490    100   850   16      17   1      0        1   39
#
#       trend
# 6254     35
# 6255     35
# 6256     35
# 6257     35
# 6258     35

# %%
comp.describe()
# Out:
#         Unnamed: 0        price        speed           hd          ram  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   3130.000000  2219.576610    52.011024   416.601694     8.286947
# std    1806.961999   580.803956    21.157735   258.548445     5.631099
# min       1.000000   949.000000    25.000000    80.000000     2.000000
# 25%    1565.500000  1794.000000    33.000000   214.000000     4.000000
# 50%    3130.000000  2144.000000    50.000000   340.000000     8.000000
# 75%    4694.500000  2595.000000    66.000000   528.000000     8.000000
# max    6259.000000  5399.000000   100.000000  2100.000000    32.000000
#
#             screen           cd        multi      premium          ads  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean     14.608723     0.464611     0.139479     0.902221   221.301007
# std       0.905115     0.498786     0.346474     0.297040    74.835284
# min      14.000000     0.000000     0.000000     0.000000    39.000000
# 25%      14.000000     0.000000     0.000000     1.000000   162.500000
# 50%      14.000000     0.000000     0.000000     1.000000   246.000000
# 75%      15.000000     1.000000     0.000000     1.000000   275.000000
# max      17.000000     1.000000     1.000000     1.000000   339.000000
#
#              trend
# count  6259.000000
# mean     15.926985
# std       7.873984
# min       1.000000
# 25%      10.000000
# 50%      16.000000
# 75%      21.500000
# max      35.000000

# %%
def Normalize(data):
    return ((data-data.min())/(data.max()-data.min()))

# %%
comp = comp.apply(Normalize)

# %%
comp.head(10)
# Out:
#    Unnamed: 0     price     speed        hd       ram    screen   cd  multi  \
# 0    0.000000  0.123596  0.000000  0.000000  0.066667  0.000000  0.0    0.0
# 1    0.000160  0.190112  0.106667  0.002475  0.000000  0.000000  0.0    0.0
# 2    0.000320  0.145169  0.000000  0.044554  0.066667  0.333333  0.0    0.0
# 3    0.000479  0.202247  0.000000  0.044554  0.200000  0.000000  0.0    0.0
# 4    0.000639  0.527191  0.106667  0.128713  0.466667  0.000000  0.0    0.0
# 5    0.000799  0.617079  0.546667  0.128713  0.466667  0.000000  0.0    0.0
# 6    0.000959  0.173258  0.000000  0.044554  0.066667  0.000000  1.0    0.0
# 7    0.001119  0.235056  0.333333  0.002475  0.000000  0.000000  0.0    0.0
# 8    0.001278  0.286742  0.333333  0.064356  0.200000  0.000000  0.0    0.0
# 9    0.001438  0.365393  0.333333  0.064356  0.066667  0.333333  0.0    0.0
#
#    premium       ads  trend
# 0      1.0  0.183333    0.0
# 1      1.0  0.183333    0.0
# 2      1.0  0.183333    0.0
# 3      0.0  0.183333    0.0
# 4      1.0  0.183333    0.0
# 5      1.0  0.183333    0.0
# 6      1.0  0.183333    0.0
# 7      1.0  0.183333    0.0
# 8      1.0  0.183333    0.0
# 9      1.0  0.183333    0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
sns.pairplot(comp)

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

import statsmodels.api as sm

# %%
xTrain,xTest ,yTrain,yTest = train_test_split(comp[['speed','hd','ram','screen','cd','multi',
                                                    'premium','ads','trend']]
                                             ,comp.price
                                              ,test_size=0.2)

# %%
def PredFun(trainX,trainY):
    
    trainX = sm.add_constant(trainX)
    
    smLM = sm.OLS(trainY,trainX).fit()
    
    return smLM

# %%
lm = PredFun(trainX = xTrain,trainY= yTrain)
# Out:
# c:\users\acer\appdata\local\programs\python\python37-32\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                     1915.
# Date:                Sat, 21 Mar 2020   Prob (F-statistic):               0.00
# Time:                        20:34:39   Log-Likelihood:                 6818.9
# No. Observations:                5007   AIC:                        -1.362e+04
# Df Residuals:                    4997   BIC:                        -1.355e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3253      0.005     69.064      0.000       0.316       0.335
# speed          0.1558      0.003     44.847      0.000       0.149       0.163
# hd             0.3532      0.014     24.852      0.000       0.325       0.381
# ram            0.3258      0.008     39.916      0.000       0.310       0.342
# screen         0.0829      0.003     27.178      0.000       0.077       0.089
# cd             0.0135      0.002      5.675      0.000       0.009       0.018
# multi          0.0242      0.003      8.411      0.000       0.019       0.030
# premium       -0.1158      0.003    -37.268      0.000      -0.122      -0.110
# ads            0.0459      0.004     11.800      0.000       0.038       0.053
# trend         -0.3949      0.005    -73.095      0.000      -0.405      -0.384
# ==============================================================================
# Omnibus:                      717.673   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2031.846
# Skew:                           0.768   Prob(JB):                         0.00
# Kurtosis:                       5.716   Cond. No.                         31.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def vif_cal(input_data, dependent_col):
    
    vif_df = pd.DataFrame( columns = ['Var', 'Vif'])
    x_vars=input_data.drop([dependent_col], axis=1)
    
    xvar_names=x_vars.columns
    
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y,x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        vif_df.loc[i] = [xvar_names[i], vif]
        
        
    return vif_df.sort_values(by = 'Vif', axis=0, ascending=False, inplace=False)

# %%
vif_cal(input_data = comp, dependent_col='price')
# Out:
#           Var     Vif
# 9       trend  228.34
# 0  Unnamed: 0  199.82
# 2          hd   11.47
# 7     premium    7.14
# 3         ram    6.63
# 8         ads    4.17
# 5          cd    3.46
# 1       speed    3.32
# 4      screen    1.57
# 6       multi    1.50

# %%
temp = xTrain.drop('hd',1)

# %%
lm = PredFun(trainX = temp,trainY= yTrain)

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     1849.
# Date:                Sat, 21 Mar 2020   Prob (F-statistic):               0.00
# Time:                        20:34:40   Log-Likelihood:                 6527.1
# No. Observations:                5007   AIC:                        -1.304e+04
# Df Residuals:                    4998   BIC:                        -1.298e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3251      0.005     65.122      0.000       0.315       0.335
# speed          0.1637      0.004     44.665      0.000       0.157       0.171
# ram            0.4762      0.006     82.008      0.000       0.465       0.488
# screen         0.0842      0.003     26.045      0.000       0.078       0.091
# cd             0.0207      0.003      8.238      0.000       0.016       0.026
# multi          0.0173      0.003      5.719      0.000       0.011       0.023
# premium       -0.1117      0.003    -33.968      0.000      -0.118      -0.105
# ads            0.0294      0.004      7.253      0.000       0.021       0.037
# trend         -0.3307      0.005    -65.753      0.000      -0.341      -0.321
# ==============================================================================
# Omnibus:                     1041.817   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3910.835
# Skew:                           0.999   Prob(JB):                         0.00
# Kurtosis:                       6.841   Cond. No.                         12.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
xTrain.head()
# Out:
#          speed        hd       ram    screen   cd  multi  premium       ads  \
# 5746  1.000000  0.455446  0.733333  1.000000  1.0    0.0      1.0  0.310000
# 5925  0.546667  0.230198  0.066667  0.000000  0.0    0.0      1.0  0.300000
# 5239  0.546667  0.321782  0.200000  1.000000  1.0    0.0      1.0  0.396667
# 5430  0.106667  0.065347  0.200000  0.333333  1.0    1.0      1.0  0.376667
# 4627  0.333333  0.128713  0.066667  1.000000  0.0    0.0      1.0  0.553333
#
#          trend
# 5746  0.794118
# 5925  0.823529
# 5239  0.705882
# 5430  0.735294
# 4627  0.588235

# %%
reg = LinearRegression()

# %%
reg = reg.fit(xTrain,yTrain)

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# 0.32528804951509405
# [ 0.15578514  0.35315707  0.32580777  0.08288988  0.01353606  0.02417873
#  -0.11582098  0.04586087 -0.39485457]

# %%
yPred = reg.predict(xTest)

# %%
Price = pd.DataFrame({'Acutal':yTest,'Predicted':yPred})

# %%
plt.figure(figsize=(18,9))

sns.lineplot(data = Price)

plt.show()

# %%
mse = mean_squared_error(yTest,yPred)
r2 = r2_score(yTest,yPred)

# %%
print(mse)
print(r2)
# Out:
# 0.0037469304311989467
# 0.7767749218440024
